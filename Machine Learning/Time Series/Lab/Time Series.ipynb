# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# # Time Series

# %% [markdown]
# ## Live Demos

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
bike_sharing_dataset = fetch_ucirepo(id=275) 
  
# data (as pandas dataframes) 
X = bike_sharing_dataset.data.features 
y = bike_sharing_dataset.data.targets 
  
# metadata 
# print(bike_sharing_dataset.metadata) 
  
# variable information 
# print(bike_sharing_dataset.variables)

# %%
X.shape, y.shape
# Out:
# ((17379, 13), (17379, 1))

# %%
X.columns, y.columns
# Out:
# (Index(['dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#         'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed'],
#        dtype='object'),
#  Index(['cnt'], dtype='object'))

# %%
X.dtypes
# Out:
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# hr              int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# dtype: object

# %%
pd.to_datetime(X.dteday)
# Out:
# 0       2011-01-01
# 1       2011-01-01
# 2       2011-01-01
# 3       2011-01-01
# 4       2011-01-01
#            ...
# 17374   2012-12-31
# 17375   2012-12-31
# 17376   2012-12-31
# 17377   2012-12-31
# 17378   2012-12-31
# Name: dteday, Length: 17379, dtype: datetime64[ns]

# %%
pd.read_csv('data/hour.csv').head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
pd.read_csv('data/day.csv').head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
X.describe().T
# Out:
#               count       mean       std   min     25%      50%      75%  \
# season      17379.0   2.501640  1.106918  1.00  2.0000   3.0000   3.0000
# yr          17379.0   0.502561  0.500008  0.00  0.0000   1.0000   1.0000
# mnth        17379.0   6.537775  3.438776  1.00  4.0000   7.0000  10.0000
# hr          17379.0  11.546752  6.914405  0.00  6.0000  12.0000  18.0000
# holiday     17379.0   0.028770  0.167165  0.00  0.0000   0.0000   0.0000
# weekday     17379.0   3.003683  2.005771  0.00  1.0000   3.0000   5.0000
# workingday  17379.0   0.682721  0.465431  0.00  0.0000   1.0000   1.0000
# weathersit  17379.0   1.425283  0.639357  1.00  1.0000   1.0000   2.0000
# temp        17379.0   0.496987  0.192556  0.02  0.3400   0.5000   0.6600
# atemp       17379.0   0.475775  0.171850  0.00  0.3333   0.4848   0.6212
# hum         17379.0   0.627229  0.192930  0.00  0.4800   0.6300   0.7800
# windspeed   17379.0   0.190098  0.122340  0.00  0.1045   0.1940   0.2537
#
# ...

# %%
plt.hist(y, bins = 'fd')
plt.xlabel('Number of rentals')
plt.ylabel('Frequency')
plt.semilogx()
plt.show()

# %%
dataframe = pd.DataFrame(bike_sharing_dataset)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1200\2230383121.py in <module>
# ----> 1 dataframe = pd.DataFrame(bike_sharing_dataset)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     634         elif isinstance(data, dict):
#     635             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637         elif isinstance(data, ma.MaskedArray):
#     638             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     500         # TODO: can we get rid of the dt64tz special case above?
#     501
# ...

# %% [markdown]
# The distribution of the target variable **y** is not lognormal.

# %%
X.resample("D")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1200\3858565117.py in <module>
# ----> 1 X.resample("D")
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset)
#   10548         offset: TimedeltaConvertibleTypes | None = None,
#   10549     ) -> Resampler:
# > 10550         return super().resample(
#   10551             rule=rule,
#   10552             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset)
#    8311
#    8312         axis = self._get_axis_number(axis)
# -> 8313         return get_resampler(
#    8314             self,
#    8315             freq=rule,
#
# ...
