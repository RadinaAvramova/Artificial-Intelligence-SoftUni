# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import make_blobs, make_circles, make_moons

from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN

# %% [markdown]
# # Clustering

# %% [markdown]
# ## Live demos

# %%
attributes, clusters = make_blobs(n_samples = 300, centers = 3, cluster_std=[0.1, 0.5,1])

# %%
plt.scatter(attributes[:,0], attributes[:,1], c = clusters)
plt.show()

# %%
k_means = KMeans(n_clusters=3, init = 'random')

# %%
k_means.fit(attributes)
# Out:
# KMeans(init='random', n_clusters=3)

# %%
k_means.cluster_centers_
# Out:
# array([[-0.23315281, -8.73558151],
#        [ 6.39482914, -0.19398442],
#        [-6.65555913,  2.525868  ]])

# %%
k_means.inertia_
# Out:
# 234.2667734036754

# %%
predictions = k_means.predict(attributes)

# %%
plt.scatter(attributes[:,0], attributes[:,1], c = predictions)
plt.scatter(k_means.cluster_centers_[:, 0], k_means.cluster_centers_[:,1], c = 'r' )
plt.show()

# %%
inertias = [] 
for i in range(1, 11):
    km = KMeans(n_clusters = i)
    km.fit(attributes)
    inertias.append(km.inertia_)
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %%
inertias
# Out:
# [15656.493605077356,
#  6078.718052229756,
#  234.2667734036754,
#  171.8920101865746,
#  132.4730038037892,
#  112.26477098899436,
#  92.73224640695622,
#  81.48216030264538,
#  71.50521751819542,
#  63.72226877890427]

# %%
plt.plot(range(1,11), inertias, marker = "o")
plt.xlabel("Number of clusters")
plt.ylabel("Inertia")
plt.show()

# %%
attributes_circles, cluster_circles = make_circles(noise=0.1, factor=0.3)

# %%
plt.scatter(attributes_circles[:,0], attributes_circles[:,1], c = cluster_circles)
plt.gca().set_aspect('equal')
plt.show()

# %%
k_means_circles = KMeans(n_clusters=2, init='random')
k_means_circles.fit(attributes_circles)
predictions_circles = k_means_circles.predict(attributes_circles)

# %%
plt.scatter(attributes_circles[:,0], attributes_circles[:,1], c = predictions_circles)
plt.gca().set_aspect('equal')
plt.scatter(k_means_circles.cluster_centers_[:,0], k_means_circles.cluster_centers_[:,1], c = 'r')
plt.show()

# %%
inertias = [] 
for i in range(1, 16):
    km = KMeans(n_clusters = i)
    km.fit(attributes_circles)
    inertias.append(km.inertia_)
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
plt.plot(range(1,16), inertias, marker = "o")
plt.xlabel("Number of clusters")
plt.ylabel("Inertia")
plt.show()

# %%
agglomerative_clustering = AgglomerativeClustering(n_clusters=3)

# %%
agglomerative_clustering.fit(attributes)
# Out:
# AgglomerativeClustering(n_clusters=3)

# %%
agglomerative_clustering.labels_
# Out:
# array([0, 0, 0, 1, 2, 0, 2, 1, 0, 2, 1, 2, 2, 1, 0, 0, 1, 2, 1, 1, 0, 0,
#        2, 1, 2, 2, 0, 1, 1, 0, 2, 2, 1, 1, 0, 1, 0, 2, 0, 0, 0, 2, 1, 1,
#        0, 2, 1, 2, 0, 2, 0, 0, 2, 0, 0, 0, 2, 0, 0, 2, 2, 2, 0, 1, 2, 1,
#        1, 2, 0, 2, 0, 2, 2, 2, 0, 0, 2, 0, 2, 1, 1, 0, 2, 2, 0, 1, 1, 2,
#        2, 2, 2, 2, 1, 2, 1, 2, 0, 1, 1, 0, 1, 1, 1, 0, 0, 0, 2, 0, 1, 0,
#        1, 0, 2, 2, 2, 1, 1, 1, 2, 1, 1, 1, 0, 2, 0, 0, 2, 2, 2, 0, 1, 1,
#        1, 2, 2, 0, 0, 1, 1, 1, 1, 0, 1, 0, 1, 0, 0, 2, 1, 0, 0, 1, 1, 0,
#        1, 1, 1, 2, 2, 2, 1, 2, 2, 0, 0, 0, 2, 0, 2, 0, 1, 0, 2, 1, 1, 0,
#        2, 0, 0, 1, 1, 2, 2, 2, 0, 1, 2, 0, 0, 0, 2, 2, 2, 1, 1, 0, 2, 0,
#        0, 1, 1, 0, 1, 2, 2, 1, 2, 0, 2, 1, 0, 2, 1, 2, 0, 0, 1, 2, 1, 1,
#        0, 1, 2, 1, 0, 1, 1, 0, 1, 2, 2, 1, 2, 0, 0, 1, 1, 2, 1, 2, 1, 1,
#        0, 2, 2, 1, 0, 1, 2, 1, 1, 0, 2, 0, 1, 2, 2, 1, 0, 2, 1, 0, 2, 2,
#        2, 0, 0, 2, 2, 2, 2, 0, 2, 1, 2, 2, 0, 0, 0, 0, 1, 1, 0, 1, 2, 1,
# ...

# %%
plt.scatter(attributes[:,0], attributes[:,1], c = agglomerative_clustering.labels_)
plt.show()

# %%
attributes_moons, clusters_moons = make_moons(noise = 0.08)

# %%
plt.scatter(attributes_moons[:,0], attributes_moons[:,1], c = clusters_moons)
plt.gca().set_aspect('equal')
plt.show()

# %%
k_mean_moons = KMeans(n_clusters=2)
k_mean_moons.fit(attributes_moons)
prediction_moons = k_mean_moons.predict(attributes_moons)

# %%
plt.scatter(attributes_moons[:,0], attributes_moons[:,1], c = prediction_moons)
plt.gca().set_aspect('equal')
plt.show()

# %%
aggl = AgglomerativeClustering(n_clusters=2)

# %%
aggl.fit(attributes_moons)
# Out:
# AgglomerativeClustering()

# %%
plt.scatter(attributes_moons[:,0], attributes_moons[:,1], c = aggl.labels_)
plt.gca().set_aspect('equal')
plt.show()

# %%
dbscan = DBSCAN(eps=0.5, min_samples=2)

# %%
clusters = dbscan.fit_predict(attributes)

# %%
(clusters == -1).sum()/len(clusters)
# Out:
# 0.02

# %%
plt.scatter(attributes[:,0], attributes[:,1], c = clusters==-1)
plt.gca().set_aspect('equal')
plt.show()
