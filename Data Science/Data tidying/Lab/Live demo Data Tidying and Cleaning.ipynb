# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Tidying and Cleaning
# ## Live Demo

# %%
pew = pd.read_csv('Data exercice/pew.csv')

# %%
pew
# Out:
#                    religion  <$10k  $10-20k  $20-30k  $30-40k  $40-50k  \
# 0                  Agnostic     27       34       60       81       76
# 1                   Atheist     12       27       37       52       35
# 2                  Buddhist     27       21       30       34       33
# 3                  Catholic    418      617      732      670      638
# 4        Don’t know/refused     15       14       15       11       10
# 5          Evangelical Prot    575      869     1064      982      881
# 6                     Hindu      1        9        7        9       11
# 7   Historically Black Prot    228      244      236      238      197
# 8         Jehovah's Witness     20       27       24       24       21
# 9                    Jewish     19       19       25       25       30
# 10            Mainline Prot    289      495      619      655      651
# 11                   Mormon     29       40       48       51       56
# ...

# %%
# The "melt" function transforms a data into a key-value pair type.
pew_tidy = pew.melt(id_vars=['religion'],
                    var_name = 'income',
                    value_name = 'frequency')

# %%
pew_tidy
# Out:
#                   religion              income  frequency
# 0                 Agnostic               <$10k         27
# 1                  Atheist               <$10k         12
# 2                 Buddhist               <$10k         27
# 3                 Catholic               <$10k        418
# 4       Don’t know/refused               <$10k         15
# ..                     ...                 ...        ...
# 175               Orthodox  Don't know/refused         73
# 176        Other Christian  Don't know/refused         18
# 177           Other Faiths  Don't know/refused         71
# 178  Other World Religions  Don't know/refused          8
# 179           Unaffiliated  Don't know/refused        597
#
# [180 rows x 3 columns]

# %%
tb = pd.read_csv('Data exercice/tb.csv')

# %%
tb
# Out:
#      iso2  year  m04   m514   m014  m1524   m2534   m3544   m4554  m5564  ...  \
# 0      AD  1989  NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN  ...
# 1      AD  1990  NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN  ...
# 2      AD  1991  NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN  ...
# 3      AD  1992  NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN  ...
# 4      AD  1993  NaN    NaN    NaN    NaN     NaN     NaN     NaN    NaN  ...
# ...   ...   ...  ...    ...    ...    ...     ...     ...     ...    ...  ...
# 5764   ZW  2004  NaN    NaN  187.0  833.0  2908.0  2298.0  1056.0  366.0  ...
# 5765   ZW  2005  NaN    NaN  210.0  837.0  2264.0  1855.0   762.0  295.0  ...
# 5766   ZW  2006  NaN    NaN  215.0  736.0  2391.0  1939.0   896.0  348.0  ...
# 5767   ZW  2007  6.0  132.0  138.0  500.0  3693.0     0.0   716.0  292.0  ...
# 5768   ZW  2008  NaN    NaN  127.0  614.0     0.0  3316.0   704.0  263.0  ...
#
# ...

# %%
# Checks for Not A Number values in iso2 column.
tb.iso2.isna().any()
# Out:
# True

# %%
tb[tb.iso2.isna()]
# Out:
#      iso2  year  m04  m514  m014  m1524   m2534  m3544  m4554  m5564  ...  \
# 3691  NaN  1985  NaN   NaN   NaN    NaN     NaN    NaN    NaN    NaN  ...
# 3692  NaN  1986  NaN   NaN   NaN    NaN     NaN    NaN    NaN    NaN  ...
# 3693  NaN  1987  NaN   NaN   NaN    NaN     NaN    NaN    NaN    NaN  ...
# 3694  NaN  1988  NaN   NaN   NaN    NaN     NaN    NaN    NaN    NaN  ...
# 3695  NaN  1989  NaN   NaN   NaN    NaN     NaN    NaN    NaN    NaN  ...
# 3696  NaN  1990  NaN   NaN   NaN    NaN     NaN    NaN    NaN    NaN  ...
# 3697  NaN  1991  NaN   NaN   NaN    NaN     NaN    NaN    NaN    NaN  ...
# 3698  NaN  1992  NaN   NaN   NaN    NaN     NaN    NaN    NaN    NaN  ...
# 3699  NaN  1993  NaN   NaN   NaN    NaN     NaN    NaN    NaN    NaN  ...
# 3700  NaN  1995  NaN   NaN   0.0   68.0   235.0  113.0   55.0   21.0  ...
# 3701  NaN  1996  NaN   NaN  16.0  205.0   613.0  472.0  230.0  137.0  ...
# 3702  NaN  1997  NaN   NaN  18.0  232.0   791.0  479.0  296.0  161.0  ...
# ...

# %%
tb.loc[tb.iso2.isna(),'iso2'] = "NA"

# %%
tb[tb.iso2.isna()]
# Out:
# Empty DataFrame
# Columns: [iso2, year, m04, m514, m014, m1524, m2534, m3544, m4554, m5564, m65, mu, f04, f514, f014, f1524, f2534, f3544, f4554, f5564, f65, fu]
# Index: []
#
# [0 rows x 22 columns]

# %%
tb.iso2.isna().any()
# Out:
# False

# %%
tb.dtypes
# Out:
# iso2      object
# year       int64
# m04      float64
# m514     float64
# m014     float64
# m1524    float64
# m2534    float64
# m3544    float64
# m4554    float64
# m5564    float64
# m65      float64
# mu       float64
# f04      float64
# f514     float64
# f014     float64
# f1524    float64
# f2534    float64
# f3544    float64
# f4554    float64
# f5564    float64
# f65      float64
# fu       float64
# dtype: object

# %%
tb.describe().T
# Out:
#         count         mean          std     min     25%     50%      75%  \
# year   5769.0  1994.229329     8.423265  1980.0  1987.0  1994.0  2002.00
# m04     392.0     8.806122    46.094789     0.0     0.0     0.0     2.00
# m514    401.0    28.975062   127.881505     0.0     0.0     1.0     8.00
# m014   2381.0    79.438051   280.489536     0.0     0.0     6.0    36.00
# m1524  2407.0   922.364769  4278.638975     0.0    10.0    92.0   511.50
# m2534  2408.0  1301.894518  5253.398971     0.0    15.0   151.5   728.00
# m3544  2415.0  1205.566046  5409.064589     0.0    16.0   134.0   591.50
# m4554  2421.0   983.515489  4780.782748     0.0    13.0    98.0   434.00
# m5564  2414.0   696.171914  3771.934518     0.0     9.0    62.0   273.75
# m65    2408.0   609.440615  3660.224592     0.0     8.0    53.0   227.25
# mu      273.0     5.710623    85.713531     0.0     0.0     0.0     0.00
# f04     393.0     6.417303    39.630100     0.0     0.0     0.0     1.00
# ...

# %%
tb.head()
# Out:
#   iso2  year  m04  m514  m014  m1524  m2534  m3544  m4554  m5564  ...  f04  \
# 0   AD  1989  NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN  ...  NaN
# 1   AD  1990  NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN  ...  NaN
# 2   AD  1991  NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN  ...  NaN
# 3   AD  1992  NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN  ...  NaN
# 4   AD  1993  NaN   NaN   NaN    NaN    NaN    NaN    NaN    NaN  ...  NaN
#
#    f514  f014  f1524  f2534  f3544  f4554  f5564  f65  fu
# 0   NaN   NaN    NaN    NaN    NaN    NaN    NaN  NaN NaN
# 1   NaN   NaN    NaN    NaN    NaN    NaN    NaN  NaN NaN
# 2   NaN   NaN    NaN    NaN    NaN    NaN    NaN  NaN NaN
# 3   NaN   NaN    NaN    NaN    NaN    NaN    NaN  NaN NaN
# 4   NaN   NaN    NaN    NaN    NaN    NaN    NaN  NaN NaN
#
# [5 rows x 22 columns]

# %%
tb.columns
# Out:
# Index(['iso2', 'year', 'm04', 'm514', 'm014', 'm1524', 'm2534', 'm3544',
#        'm4554', 'm5564', 'm65', 'mu', 'f04', 'f514', 'f014', 'f1524', 'f2534',
#        'f3544', 'f4554', 'f5564', 'f65', 'fu'],
#       dtype='object')

# %%
tb_tidy = tb.melt(id_vars=['iso2', 'year'], var_name = 'sex_and_age', value_name = 'cases')

# %%
# Dropna() remove the rows which contains NaN
tb_tidy = tb_tidy.dropna()

# %%
tb_tidy
# Out:
#        iso2  year sex_and_age  cases
# 15       AD  2005         m04    0.0
# 16       AD  2006         m04    0.0
# 18       AD  2008         m04    0.0
# 42       AE  2006         m04    0.0
# 43       AE  2007         m04    0.0
# ...     ...   ...         ...    ...
# 115195   VU  2008          fu    0.0
# 115269   YE  2008          fu    0.0
# 115323   ZA  2008          fu    0.0
# 115350   ZM  2008          fu    0.0
# 115379   ZW  2008          fu    0.0
#
# [35750 rows x 4 columns]

# %%
tb_tidy.sex_and_age.str.slice(0,1)
# Out:
# 15        m
# 16        m
# 18        m
# 42        m
# 43        m
#          ..
# 115195    f
# 115269    f
# 115323    f
# 115350    f
# 115379    f
# Name: sex_and_age, Length: 35750, dtype: object

# %%
# Creating new column
tb_tidy['sex'] = tb_tidy.sex_and_age.str.slice(0,1)
tb_tidy['age_group'] = tb_tidy.sex_and_age.str.slice(1,)

# %%
tb_tidy['sex']
# Out:
# 15        m
# 16        m
# 18        m
# 42        m
# 43        m
#          ..
# 115195    f
# 115269    f
# 115323    f
# 115350    f
# 115379    f
# Name: sex, Length: 35750, dtype: object

# %%
 tb_tidy['age_group']
# Out:
# 15        04
# 16        04
# 18        04
# 42        04
# 43        04
#           ..
# 115195     u
# 115269     u
# 115323     u
# 115350     u
# 115379     u
# Name: age_group, Length: 35750, dtype: object

# %%
# Drop the column 
tb_tidy=tb_tidy.drop(columns = ['sex_and_age'])

# %%
tb_tidy
# Out:
#        iso2  year  cases sex age_group
# 15       AD  2005    0.0   m        04
# 16       AD  2006    0.0   m        04
# 18       AD  2008    0.0   m        04
# 42       AE  2006    0.0   m        04
# 43       AE  2007    0.0   m        04
# ...     ...   ...    ...  ..       ...
# 115195   VU  2008    0.0   f         u
# 115269   YE  2008    0.0   f         u
# 115323   ZA  2008    0.0   f         u
# 115350   ZM  2008    0.0   f         u
# 115379   ZW  2008    0.0   f         u
#
# [35750 rows x 5 columns]

# %%
tb_tidy = tb_tidy.sort_values(['iso2', 'year'])

# %%
tb_tidy
# Out:
#        iso2  year   cases sex age_group
# 11544    AD  1996     0.0   m       014
# 17313    AD  1996     0.0   m      1524
# 23082    AD  1996     0.0   m      2534
# 28851    AD  1996     4.0   m      3544
# 34620    AD  1996     1.0   m      4554
# ...     ...   ...     ...  ..       ...
# 92303    ZW  2008  2890.0   f      3544
# 98072    ZW  2008   467.0   f      4554
# 103841   ZW  2008   174.0   f      5564
# 109610   ZW  2008   105.0   f        65
# 115379   ZW  2008     0.0   f         u
#
# [35750 rows x 5 columns]

# %%
weather_data = pd.read_csv('Data exercice/weather.csv')

# %%
weather_data
# Out:
#          id  year  month element    d1    d2    d3    d4    d5    d6  ...  \
# 0   MX17004  2010      1    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1   MX17004  2010      1    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2   MX17004  2010      2    tmax   NaN  27.3  24.1   NaN   NaN   NaN  ...
# 3   MX17004  2010      2    tmin   NaN  14.4  14.4   NaN   NaN   NaN  ...
# 4   MX17004  2010      3    tmax   NaN   NaN   NaN   NaN  32.1   NaN  ...
# 5   MX17004  2010      3    tmin   NaN   NaN   NaN   NaN  14.2   NaN  ...
# 6   MX17004  2010      4    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 7   MX17004  2010      4    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 8   MX17004  2010      5    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 9   MX17004  2010      5    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 10  MX17004  2010      6    tmax   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 11  MX17004  2010      6    tmin   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ...

# %%
weather_data.element.unique()
# Out:
# array(['tmax', 'tmin'], dtype=object)

# %%
weather_data = weather_data.melt(id_vars =  ['id','year','month','element'], var_name = 'day')

# %%
weather_data.day = weather_data.day.str.slice(1).astype(int)

# %%
weather_data.day
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 677    31
# 678    31
# 679    31
# 680    31
# 681    31
# Name: day, Length: 682, dtype: int32

# %%
weather_data = weather_data.pivot_table(index = ['id', 'year', 'month', 'day'], columns = 'element', values = 'value')

# %%
weather_data = weather_data.reset_index()

# %%
weather_data
# Out:
# element       id  year  month  day  tmax  tmin
# 0        MX17004  2010      1   30  27.8  14.5
# 1        MX17004  2010      2    2  27.3  14.4
# 2        MX17004  2010      2    3  24.1  14.4
# 3        MX17004  2010      2   11  29.7  13.4
# 4        MX17004  2010      2   23  29.9  10.7
# 5        MX17004  2010      3    5  32.1  14.2
# 6        MX17004  2010      3   10  34.5  16.8
# 7        MX17004  2010      3   16  31.1  17.6
# 8        MX17004  2010      4   27  36.3  16.7
# 9        MX17004  2010      5   27  33.2  18.2
# 10       MX17004  2010      6   17  28.0  17.5
# 11       MX17004  2010      6   29  30.1  18.0
# 12       MX17004  2010      7    3  28.6  17.5
# 13       MX17004  2010      7   14  29.9  16.5
# 14       MX17004  2010      8   23  26.4  15.0
# 15       MX17004  2010      8    5  29.6  15.8
# 16       MX17004  2010      8   29  28.0  15.3
# 17       MX17004  2010      8    8  29.0  17.3
# 18       MX17004  2010      8   13  29.8  16.5
# ...

# %%
# Rearrange columns 
weather_data[['id', 'year', 'month', 'day', 'tmin', 'tmax']]
# Out:
# element       id  year  month  day  tmin  tmax
# 0        MX17004  2010      1   30  14.5  27.8
# 1        MX17004  2010      2    2  14.4  27.3
# 2        MX17004  2010      2    3  14.4  24.1
# 3        MX17004  2010      2   11  13.4  29.7
# 4        MX17004  2010      2   23  10.7  29.9
# 5        MX17004  2010      3    5  14.2  32.1
# 6        MX17004  2010      3   10  16.8  34.5
# 7        MX17004  2010      3   16  17.6  31.1
# 8        MX17004  2010      4   27  16.7  36.3
# 9        MX17004  2010      5   27  18.2  33.2
# 10       MX17004  2010      6   17  17.5  28.0
# 11       MX17004  2010      6   29  18.0  30.1
# 12       MX17004  2010      7    3  17.5  28.6
# 13       MX17004  2010      7   14  16.5  29.9
# 14       MX17004  2010      8   23  15.0  26.4
# 15       MX17004  2010      8    5  15.8  29.6
# 16       MX17004  2010      8   29  15.3  28.0
# 17       MX17004  2010      8    8  17.3  29.0
# 18       MX17004  2010      8   13  16.5  29.8
# ...

# %%
weather_data['date'] = pd.to_datetime(weather_data[['year', 'month', 'day']])

# %%
weather_data
# Out:
# element       id  year  month  day  tmax  tmin       date
# 0        MX17004  2010      1   30  27.8  14.5 2010-01-30
# 1        MX17004  2010      2    2  27.3  14.4 2010-02-02
# 2        MX17004  2010      2    3  24.1  14.4 2010-02-03
# 3        MX17004  2010      2   11  29.7  13.4 2010-02-11
# 4        MX17004  2010      2   23  29.9  10.7 2010-02-23
# 5        MX17004  2010      3    5  32.1  14.2 2010-03-05
# 6        MX17004  2010      3   10  34.5  16.8 2010-03-10
# 7        MX17004  2010      3   16  31.1  17.6 2010-03-16
# 8        MX17004  2010      4   27  36.3  16.7 2010-04-27
# 9        MX17004  2010      5   27  33.2  18.2 2010-05-27
# 10       MX17004  2010      6   17  28.0  17.5 2010-06-17
# 11       MX17004  2010      6   29  30.1  18.0 2010-06-29
# 12       MX17004  2010      7    3  28.6  17.5 2010-07-03
# 13       MX17004  2010      7   14  29.9  16.5 2010-07-14
# 14       MX17004  2010      8   23  26.4  15.0 2010-08-23
# ...

# %%
weather_data = weather_data.drop(columns = ['year', 'month', 'day'])
# Out:
# element       id  tmax  tmin       date
# 0        MX17004  27.8  14.5 2010-01-30
# 1        MX17004  27.3  14.4 2010-02-02
# 2        MX17004  24.1  14.4 2010-02-03
# 3        MX17004  29.7  13.4 2010-02-11
# 4        MX17004  29.9  10.7 2010-02-23
# 5        MX17004  32.1  14.2 2010-03-05
# 6        MX17004  34.5  16.8 2010-03-10
# 7        MX17004  31.1  17.6 2010-03-16
# 8        MX17004  36.3  16.7 2010-04-27
# 9        MX17004  33.2  18.2 2010-05-27
# 10       MX17004  28.0  17.5 2010-06-17
# 11       MX17004  30.1  18.0 2010-06-29
# 12       MX17004  28.6  17.5 2010-07-03
# 13       MX17004  29.9  16.5 2010-07-14
# 14       MX17004  26.4  15.0 2010-08-23
# 15       MX17004  29.6  15.8 2010-08-05
# 16       MX17004  28.0  15.3 2010-08-29
# 17       MX17004  29.0  17.3 2010-08-08
# 18       MX17004  29.8  16.5 2010-08-13
# 19       MX17004  29.7  15.6 2010-08-25
# 20       MX17004  25.4  15.4 2010-08-31
# 21       MX17004  27.0  14.0 2010-10-05
# ...

# %%
weather_data = weather_data[['date', 'tmin', 'tmax']]

# %%
# Save new file
weather_data.to_csv('Data exercice/weather_data_tidy.csv', index= None)

# %%
billboard = pd.read_csv('Data exercice/billboard.csv')

# %%
billboard = billboard.rename(columns = {'date.entered': 'date_entered'})

# %%
billboard
# Out:
#      year            artist                    track  time date_entered  wk1  \
# 0    2000             2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26   87
# 1    2000           2Ge+her  The Hardest Part Of ...  3:15   2000-09-02   91
# 2    2000      3 Doors Down               Kryptonite  3:53   2000-04-08   81
# 3    2000      3 Doors Down                    Loser  4:24   2000-10-21   76
# 4    2000          504 Boyz            Wobble Wobble  3:35   2000-04-15   57
# ..    ...               ...                      ...   ...          ...  ...
# 312  2000       Yankee Grey     Another Nine Minutes  3:10   2000-04-29   86
# 313  2000  Yearwood, Trisha          Real Live Woman  3:55   2000-04-01   85
# 314  2000   Ying Yang Twins  Whistle While You Tw...  4:19   2000-03-18   95
# 315  2000     Zombie Nation            Kernkraft 400  3:30   2000-09-02   99
# 316  2000   matchbox twenty                     Bent  4:12   2000-04-29   60
#
# ...

# %%
# Takes these values which are NaN
billboard[billboard.wk65.notna()]
# Out:
#     year artist   track  time date_entered  wk1   wk2   wk3   wk4   wk5  ...  \
# 62  2000  Creed  Higher  5:16   1999-09-11   81  77.0  73.0  63.0  61.0  ...
#
#     wk67  wk68  wk69  wk70  wk71  wk72  wk73  wk74  wk75  wk76
# 62   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [1 rows x 81 columns]

# %%
billboard_tidy = billboard.melt(id_vars = ['year', 'artist', 'track', 'time', 'date_entered'], var_name = 'week', value_name = 'position')

# %%
billboard_tidy.week.str.startswith('wk').all()
# Out:
# True

# %%
billboard_tidy.week = billboard_tidy.week.str.slice(2).astype(int)

# %%
billboard_tidy
# Out:
#        year            artist                    track  time date_entered  \
# 0      2000             2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26
# 1      2000           2Ge+her  The Hardest Part Of ...  3:15   2000-09-02
# 2      2000      3 Doors Down               Kryptonite  3:53   2000-04-08
# 3      2000      3 Doors Down                    Loser  4:24   2000-10-21
# 4      2000          504 Boyz            Wobble Wobble  3:35   2000-04-15
# ...     ...               ...                      ...   ...          ...
# 24087  2000       Yankee Grey     Another Nine Minutes  3:10   2000-04-29
# 24088  2000  Yearwood, Trisha          Real Live Woman  3:55   2000-04-01
# 24089  2000   Ying Yang Twins  Whistle While You Tw...  4:19   2000-03-18
# 24090  2000     Zombie Nation            Kernkraft 400  3:30   2000-09-02
# 24091  2000   matchbox twenty                     Bent  4:12   2000-04-29
#
#        week  position
# 0         1      87.0
# 1         1      91.0
# ...

# %%
billboard_tidy = billboard_tidy.dropna()

# %%
billboard_tidy
# Out:
#        year        artist                    track  time date_entered  week  \
# 0      2000         2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26     1
# 1      2000       2Ge+her  The Hardest Part Of ...  3:15   2000-09-02     1
# 2      2000  3 Doors Down               Kryptonite  3:53   2000-04-08     1
# 3      2000  3 Doors Down                    Loser  4:24   2000-10-21     1
# 4      2000      504 Boyz            Wobble Wobble  3:35   2000-04-15     1
# ...     ...           ...                      ...   ...          ...   ...
# 19716  2000         Creed                   Higher  5:16   1999-09-11    63
# 19833  2000      Lonestar                   Amazed  4:25   1999-06-05    63
# 20033  2000         Creed                   Higher  5:16   1999-09-11    64
# 20150  2000      Lonestar                   Amazed  4:25   1999-06-05    64
# 20350  2000         Creed                   Higher  5:16   1999-09-11    65
#
#        position
# 0          87.0
# 1          91.0
# ...

# %%
billboard_tidy.year.unique()
# Out:
# array([2000], dtype=int64)

# %%
billboard_tidy[(billboard_tidy.artist == '3 Doors Down') &
              (billboard_tidy.track == 'Kryptonite')]
# Out:
#        year        artist       track  time date_entered  week  position
# 2      2000  3 Doors Down  Kryptonite  3:53   2000-04-08     1      81.0
# 319    2000  3 Doors Down  Kryptonite  3:53   2000-04-08     2      70.0
# 636    2000  3 Doors Down  Kryptonite  3:53   2000-04-08     3      68.0
# 953    2000  3 Doors Down  Kryptonite  3:53   2000-04-08     4      67.0
# 1270   2000  3 Doors Down  Kryptonite  3:53   2000-04-08     5      66.0
# 1587   2000  3 Doors Down  Kryptonite  3:53   2000-04-08     6      57.0
# 1904   2000  3 Doors Down  Kryptonite  3:53   2000-04-08     7      54.0
# 2221   2000  3 Doors Down  Kryptonite  3:53   2000-04-08     8      53.0
# 2538   2000  3 Doors Down  Kryptonite  3:53   2000-04-08     9      51.0
# 2855   2000  3 Doors Down  Kryptonite  3:53   2000-04-08    10      51.0
# 3172   2000  3 Doors Down  Kryptonite  3:53   2000-04-08    11      51.0
# 3489   2000  3 Doors Down  Kryptonite  3:53   2000-04-08    12      51.0
# ...

# %%
# Drop_duplicates drops off 
billboard_tidy[['track', 'artist', 'time']].drop_duplicates()
# Out:
#                        track            artist  time
# 0    Baby Don't Cry (Keep...             2 Pac  4:22
# 1    The Hardest Part Of ...           2Ge+her  3:15
# 2                 Kryptonite      3 Doors Down  3:53
# 3                      Loser      3 Doors Down  4:24
# 4              Wobble Wobble          504 Boyz  3:35
# ..                       ...               ...   ...
# 312     Another Nine Minutes       Yankee Grey  3:10
# 313          Real Live Woman  Yearwood, Trisha  3:55
# 314  Whistle While You Tw...   Ying Yang Twins  4:19
# 315            Kernkraft 400     Zombie Nation  3:30
# 316                     Bent   matchbox twenty  4:12
#
# [317 rows x 3 columns]

# %% [markdown]
# ## Tools for data

# %%
# Return first n rows
billboard_tidy.head(10)
# Out:
#    year          artist                    track  time date_entered  week  \
# 0  2000           2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26     1
# 1  2000         2Ge+her  The Hardest Part Of ...  3:15   2000-09-02     1
# 2  2000    3 Doors Down               Kryptonite  3:53   2000-04-08     1
# 3  2000    3 Doors Down                    Loser  4:24   2000-10-21     1
# 4  2000        504 Boyz            Wobble Wobble  3:35   2000-04-15     1
# 5  2000            98^0  Give Me Just One Nig...  3:24   2000-08-19     1
# 6  2000         A*Teens            Dancing Queen  3:44   2000-07-08     1
# 7  2000         Aaliyah            I Don't Wanna  4:15   2000-01-29     1
# 8  2000         Aaliyah                Try Again  4:03   2000-03-18     1
# 9  2000  Adams, Yolanda            Open My Heart  5:30   2000-08-26     1
#
#    position
# 0      87.0
# 1      91.0
# 2      81.0
# 3      76.0
# 4      57.0
# 5      51.0
# 6      97.0
# 7      84.0
# 8      59.0
# 9      76.0

# %%
# Return last n rows
billboard_tidy.tail(10)
# Out:
#        year    artist   track  time date_entered  week  position
# 18882  2000  Lonestar  Amazed  4:25   1999-06-05    60      37.0
# 19082  2000     Creed  Higher  5:16   1999-09-11    61      43.0
# 19199  2000  Lonestar  Amazed  4:25   1999-06-05    61      42.0
# 19399  2000     Creed  Higher  5:16   1999-09-11    62      47.0
# 19516  2000  Lonestar  Amazed  4:25   1999-06-05    62      42.0
# 19716  2000     Creed  Higher  5:16   1999-09-11    63      50.0
# 19833  2000  Lonestar  Amazed  4:25   1999-06-05    63      45.0
# 20033  2000     Creed  Higher  5:16   1999-09-11    64      50.0
# 20150  2000  Lonestar  Amazed  4:25   1999-06-05    64      50.0
# 20350  2000     Creed  Higher  5:16   1999-09-11    65      49.0

# %%
# Returns first n smallest values of a given column
billboard_tidy.nsmallest(3, 'position')
# Out:
#       year               artist              track  time date_entered  week  \
# 1776  2000              Madonna              Music  3:45   2000-08-12     6
# 2093  2000              Madonna              Music  3:45   2000-08-12     7
# 2232  2000  Aguilera, Christina  What A Girl Wants  3:18   1999-11-27     8
#
#       position
# 1776       1.0
# 2093       1.0
# 2232       1.0

# %%
# Returns first n largest values of a given column
weather_data.nlargest(6, 'tmax')
# Out:
# element       date  tmin  tmax
# 8       2010-04-27  16.7  36.3
# 6       2010-03-10  16.8  34.5
# 9       2010-05-27  18.2  33.2
# 5       2010-03-05  14.2  32.1
# 26      2010-11-02  16.3  31.3
# 25      2010-10-28  15.0  31.2

# %%
# Syntax for filtration by columns
weather_data[(weather_data.tmin >= 16) & (weather_data.tmin <= 22)]
# Out:
# element       date  tmin  tmax
# 6       2010-03-10  16.8  34.5
# 7       2010-03-16  17.6  31.1
# 8       2010-04-27  16.7  36.3
# 9       2010-05-27  18.2  33.2
# 10      2010-06-17  17.5  28.0
# 11      2010-06-29  18.0  30.1
# 12      2010-07-03  17.5  28.6
# 13      2010-07-14  16.5  29.9
# 17      2010-08-08  17.3  29.0
# 18      2010-08-13  16.5  29.8
# 26      2010-11-02  16.3  31.3

# %%
weather_data[(weather_data.tmin >= 16) & (weather_data.tmin <= 22) & (weather_data.date.dt.month == 7)]
# Out:
# element       date  tmin  tmax
# 12      2010-07-03  17.5  28.6
# 13      2010-07-14  16.5  29.9

# %%
# Rearange columns by choice
billboard_tidy[['artist', 'track']].head(5)
# Out:
#          artist                    track
# 0         2 Pac  Baby Don't Cry (Keep...
# 1       2Ge+her  The Hardest Part Of ...
# 2  3 Doors Down               Kryptonite
# 3  3 Doors Down                    Loser
# 4      504 Boyz            Wobble Wobble

# %%
# Projection
billboard.artist.str.slice(0, 5)
# Out:
# 0      2 Pac
# 1      2Ge+h
# 2      3 Doo
# 3      3 Doo
# 4      504 B
#        ...
# 312    Yanke
# 313    Yearw
# 314    Ying
# 315    Zombi
# 316    match
# Name: artist, Length: 317, dtype: object

# %%
# Create new column.
billboard['artist_short_name'] = billboard.artist.str.slice(0, 5) + '...'
billboard
# Out:
#      year            artist                    track  time date_entered  wk1  \
# 0    2000             2 Pac  Baby Don't Cry (Keep...  4:22   2000-02-26   87
# 1    2000           2Ge+her  The Hardest Part Of ...  3:15   2000-09-02   91
# 2    2000      3 Doors Down               Kryptonite  3:53   2000-04-08   81
# 3    2000      3 Doors Down                    Loser  4:24   2000-10-21   76
# 4    2000          504 Boyz            Wobble Wobble  3:35   2000-04-15   57
# ..    ...               ...                      ...   ...          ...  ...
# 312  2000       Yankee Grey     Another Nine Minutes  3:10   2000-04-29   86
# 313  2000  Yearwood, Trisha          Real Live Woman  3:55   2000-04-01   85
# 314  2000   Ying Yang Twins  Whistle While You Tw...  4:19   2000-03-18   95
# 315  2000     Zombie Nation            Kernkraft 400  3:30   2000-09-02   99
# 316  2000   matchbox twenty                     Bent  4:12   2000-04-29   60
#
# ...

# %%
billboard_tidy.describe().T
# Out:
#            count         mean        std     min     25%     50%     75%  \
# year      5307.0  2000.000000   0.000000  2000.0  2000.0  2000.0  2000.0
# week      5307.0    11.470699   9.001300     1.0     5.0    10.0    16.0
# position  5307.0    51.052384  28.966198     1.0    26.0    51.0    76.0
#
#              max
# year      2000.0
# week        65.0
# position   100.0

# %%
# Grouping data
mean_counts_by_religion = pew_tidy.groupby('religion').frequency.mean().sort_values()

# %%
mean_counts_by_religion
# Out:
# religion
# Other World Religions        4.2
# Muslim                      11.6
# Other Christian             12.9
# Jehovah's Witness           21.5
# Hindu                       25.7
# Don’t know/refused          27.2
# Orthodox                    36.3
# Buddhist                    41.1
# Other Faiths                44.9
# Atheist                     51.5
# Mormon                      58.1
# Jewish                      68.2
# Agnostic                    82.6
# Historically Black Prot    199.5
# Unaffiliated               370.7
# Mainline Prot              747.0
# Catholic                   805.4
# Evangelical Prot           947.2
# Name: frequency, dtype: float64

# %%
# Grouping returns a tuple with two values - the group and its values.
for key, value in pew_tidy.groupby('religion'):
    print(key, value.frequency.min(), value.frequency.mean(), value.frequency.max(), sep = ', ')
# Out:
# Agnostic, 27, 82.6, 137
# Atheist, 12, 51.5, 76
# Buddhist, 21, 41.1, 62
# Catholic, 418, 805.4, 1489
# Don’t know/refused, 10, 27.2, 116
# Evangelical Prot, 414, 947.2, 1529
# Hindu, 1, 25.7, 54
# Historically Black Prot, 78, 199.5, 339
# Jehovah's Witness, 6, 21.5, 37
# Jewish, 19, 68.2, 162
# Mainline Prot, 289, 747.0, 1328
# Mormon, 29, 58.1, 112
# Muslim, 6, 11.6, 23
# Orthodox, 13, 36.3, 73
# Other Christian, 7, 12.9, 18
# Other Faiths, 20, 44.9, 71
# Other World Religions, 2, 4.2, 8
# Unaffiliated, 217, 370.7, 597

# %%
plt.barh(mean_counts_by_religion.index, mean_counts_by_religion)
plt.xlabel('Mean number of peaple')
plt.title('Mean number of people bu religion')
plt.show()

# %%
# Creating data frame
aggregates = {
    'religion' : [],
    'mean' : [],
    'min' : [],    
    'max' : [],
    
}
for key, value in pew_tidy.groupby('religion'):
    
    aggregates['religion'].append(key)
    aggregates['mean'].append(value.frequency.mean())
    aggregates['min'].append(value.frequency.min())
    aggregates['max'].append(value.frequency.max())
    
    
aggregates_tidy = pd.DataFrame(aggregates)
aggregates_tidy
# Out:
#                    religion   mean  min   max
# 0                  Agnostic   82.6   27   137
# 1                   Atheist   51.5   12    76
# 2                  Buddhist   41.1   21    62
# 3                  Catholic  805.4  418  1489
# 4        Don’t know/refused   27.2   10   116
# 5          Evangelical Prot  947.2  414  1529
# 6                     Hindu   25.7    1    54
# 7   Historically Black Prot  199.5   78   339
# 8         Jehovah's Witness   21.5    6    37
# 9                    Jewish   68.2   19   162
# 10            Mainline Prot  747.0  289  1328
# 11                   Mormon   58.1   29   112
# 12                   Muslim   11.6    6    23
# 13                 Orthodox   36.3   13    73
# 14          Other Christian   12.9    7    18
# 15             Other Faiths   44.9   20    71
# 16    Other World Religions    4.2    2     8
# 17             Unaffiliated  370.7  217   597

# %% [markdown]
# # Cleaning data

# %%
us_weather_data = pd.read_csv('https://raw.githubusercontent.com/synesthesiam/blog/master/posts/data/weather_year.csv')

# %%
us_weather_data
# Out:
#            EDT  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0    2012-3-10                56                 40                24
# 1    2012-3-11                67                 49                30
# 2    2012-3-12                71                 62                53
# 3    2012-3-13                76                 63                50
# 4    2012-3-14                80                 62                44
# ..         ...               ...                ...               ...
# 361   2013-3-6                32                 31                29
# 362   2013-3-7                36                 32                28
# 363   2013-3-8                47                 35                23
# 364   2013-3-9                56                 45                33
# 365  2013-3-10                60                 52                50
#
#      Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# ...

# %%
us_weather_data.shape
# Out:
# (366, 23)

# %%
us_weather_data.dtypes
# Out:
# EDT                            object
# Max TemperatureF                int64
# Mean TemperatureF               int64
# Min TemperatureF                int64
# Max Dew PointF                  int64
# MeanDew PointF                  int64
# Min DewpointF                   int64
# Max Humidity                    int64
#  Mean Humidity                  int64
#  Min Humidity                   int64
#  Max Sea Level PressureIn     float64
#  Mean Sea Level PressureIn    float64
#  Min Sea Level PressureIn     float64
#  Max VisibilityMiles            int64
#  Mean VisibilityMiles           int64
#  Min VisibilityMiles            int64
#  Max Wind SpeedMPH              int64
#  Mean Wind SpeedMPH             int64
#  Max Gust SpeedMPH            float64
# PrecipitationIn                object
#  CloudCover                     int64
#  Events                        object
#  WindDirDegrees                 int64
# dtype: object

# %%
# Remove the starting space 
us_weather_data.columns= [column.strip() for column in us_weather_data.columns]

# %%
us_weather_data.dtypes
# Out:
# EDT                           object
# Max TemperatureF               int64
# Mean TemperatureF              int64
# Min TemperatureF               int64
# Max Dew PointF                 int64
# MeanDew PointF                 int64
# Min DewpointF                  int64
# Max Humidity                   int64
# Mean Humidity                  int64
# Min Humidity                   int64
# Max Sea Level PressureIn     float64
# Mean Sea Level PressureIn    float64
# Min Sea Level PressureIn     float64
# Max VisibilityMiles            int64
# Mean VisibilityMiles           int64
# Min VisibilityMiles            int64
# Max Wind SpeedMPH              int64
# Mean Wind SpeedMPH             int64
# Max Gust SpeedMPH            float64
# PrecipitationIn               object
# CloudCover                     int64
# Events                        object
# WindDirDegrees                 int64
# dtype: object

# %%
# Same operation with function
us_weather_data = us_weather_data.rename(columns = lambda x: x.strip())

# %%
us_weather_data['PrecipitationIn'].unique
# Out:
# <bound method Series.unique of 0      0.00
# 1         T
# 2      0.03
# 3      0.00
# 4      0.00
#        ...
# 361    0.04
# 362    0.00
# 363    0.00
# 364       T
# 365    0.00
# Name: PrecipitationIn, Length: 366, dtype: object>

# %%
a = []
for col in us_weather_data.columns:
    new_col = col.replace(' ', '_').lower()
    if new_col[-1] == 'f':
        new_col = new_col[:-1]
    a.append(new_col)
us_weather_data.columns = a
us_weather_data.columns
# Out:
# Index(['edt', 'max_temperature', 'mean_temperature', 'min_temperature',
#        'max_dew_point', 'meandew_point', 'min_dewpoint', 'max_humidity',
#        'mean_humidity', 'min_humidity', 'max_sea_level_pressurein',
#        'mean_sea_level_pressurein', 'min_sea_level_pressurein',
#        'max_visibilitymiles', 'mean_visibilitymiles', 'min_visibilitymiles',
#        'max_wind_speedmph', 'mean_wind_speedmph', 'max_gust_speedmph',
#        'precipitationin', 'cloudcover', 'events', 'winddirdegrees'],
#       dtype='object')

# %%
us_weather_data.describe().T
# Out:
#                            count        mean        std    min     25%  \
# max_temperature            366.0   66.803279  20.361247  16.00   51.00
# mean_temperature           366.0   55.683060  18.436506  11.00   41.00
# min_temperature            366.0   44.101093  17.301141   1.00   30.00
# max_dew_point              366.0   49.549180  16.397178   0.00   36.00
# meandew_point              366.0   44.057377  16.829996  -3.00   30.00
# min_dewpoint               366.0   37.980874  17.479449  -5.00   24.00
# max_humidity               366.0   90.027322   9.108438  54.00   85.00
# mean_humidity              366.0   67.860656   9.945591  37.00   61.25
# min_humidity               366.0   45.193989  15.360261  15.00   35.00
# max_sea_level_pressurein   366.0   30.108907   0.172189  29.64   29.99
# mean_sea_level_pressurein  366.0   30.022705   0.174112  29.42   29.91
# min_sea_level_pressurein   366.0   29.936831   0.182476  29.23   29.83
# ...

# %%
us_weather_data.precipitationin.unique()
# Out:
# array(['0.00', 'T', '0.03', '0.04', '0.14', '0.86', '0.06', '0.01',
#        '0.51', '0.69', '1.45', '0.38', '0.19', '0.15', '0.49', '0.29',
#        '0.09', '0.90', '0.02', '0.07', '0.13', '0.10', '0.36', '0.27',
#        '0.16', '0.26', '0.31', '0.05', '0.32', '1.85', '0.53', '2.00',
#        '0.92', '1.10', '0.17', '1.13', '0.63', '0.50', '0.71', '0.73',
#        '1.52', '0.47', '0.39', '0.18', '0.77', '0.08', '0.33', '0.44',
#        '0.48', '0.20', '0.12', '0.82', '1.16', '1.73', '0.40', '0.99',
#        '0.30', '1.17'], dtype=object)

# %%
us_weather_data.loc[us_weather_data.precipitationin == 'T', 'precipitationin'] = 1e-4

# %%
us_weather_data.precipitationin.astype(float)
# Out:
# 0      0.0000
# 1      0.0001
# 2      0.0300
# 3      0.0000
# 4      0.0000
#         ...
# 361    0.0400
# 362    0.0000
# 363    0.0000
# 364    0.0001
# 365    0.0000
# Name: precipitationin, Length: 366, dtype: float64

# %%
titanic_data = pd.read_csv('https://raw.githubusercontent.com/Geoyi/Cleaning-Titanic-Data/master/titanic_original.csv')

# %%
titanic_data
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1305     3.0       0.0                            Zabour, Miss. Thamine
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
# 1307     3.0       0.0                              Zakarian, Mr. Ortin
# 1308     3.0       0.0                               Zimmerman, Mr. Leo
# 1309     NaN       NaN                                              NaN
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
for column in titanic_data.columns:
    print(f'{column}: {len(titanic_data[titanic_data[column].isna()])}')
# Out:
# pclass: 1
# survived: 1
# name: 1
# sex: 1
# age: 264
# sibsp: 1
# parch: 1
# ticket: 1
# fare: 2
# cabin: 1015
# embarked: 3
# boat: 824
# body: 1189
# home.dest: 565

# %%
titanic_data.body
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3       135.0
# 4         NaN
#         ...
# 1305      NaN
# 1306    304.0
# 1307      NaN
# 1308      NaN
# 1309      NaN
# Name: body, Length: 1310, dtype: float64

# %%
iris = pd.read_csv('Data exercice/iris.data', header = None)
iris.columns = ['sepal length', 'sepal width', 'petal length', 'petal width', 'class']
iris
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
print(set(iris['class']))
# Out:
# {'Iris-setosa', 'Iris-virginica', 'Iris-versicolor'}

# %%
iris.dtypes
# Out:
# sepal length    float64
# sepal width     float64
# petal length    float64
# petal width     float64
# class            object
# dtype: object

# %%
sepal_length_between = iris[(iris['sepal length']>=4.5) & (iris['sepal length']<=10)]

# %%
round(sepal_length_between['petal length'].mean(), 2)
# Out:
# 3.83

# %%
sepal_length_between.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count    146.000000   146.000000    146.000000   146.000000
# mean       5.883562     3.054795      3.826712     1.226712
# std        0.802155     0.439134      1.738937     0.754142
# min        4.500000     2.000000      1.000000     0.100000
# 25%        5.125000     2.800000      1.600000     0.325000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
red_wines = pd.read_csv('Data exercice/winequality-red.csv')

# %%
red_wines
# Out:
#      fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 0      7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5
# 1      7.8;0.88;0;2.6;0.098;25;67;0.9968;3.2;0.68;9.8;5
# 2     7.8;0.76;0.04;2.3;0.092;15;54;0.997;3.26;0.65;...
# 3     11.2;0.28;0.56;1.9;0.075;17;60;0.998;3.16;0.58...
# 4      7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5
# ...                                                 ...
# 1594  6.2;0.6;0.08;2;0.09;32;44;0.9949;3.45;0.58;10.5;5
# 1595  5.9;0.55;0.1;2.2;0.062;39;51;0.99512;3.52;0.76...
# 1596  6.3;0.51;0.13;2.3;0.076;29;40;0.99574;3.42;0.7...
# 1597  5.9;0.645;0.12;2;0.075;32;44;0.99547;3.57;0.71...
# 1598  6;0.31;0.47;3.6;0.067;18;42;0.99549;3.39;0.66;...
#
# [1599 rows x 1 columns]

# %%
rows = []
for data in red_wines.values:
    new_data= data[0].replace(';', ',').split(',')
    new_data = list(map(float, new_data))
    rows.append(new_data)
    # print(new_data, len(new_data))
rows = np.array(rows)
rows[:,0]
# Out:
# array([7.4, 7.8, 7.8, ..., 6.3, 5.9, 6. ])

# %%
new_columns = {0: 'fixed acidity',1: 'volatile acidity',2:'citric acid',
                     3: 'residual sugar', 4: 'chlorides', 5: 'free sulfur dioxide', 
                     6: 'total sulfur dioxide', 7: 'density', 8: 'pH', 9: 'sulphates',
                     10: 'alcohol', 11:'quality'}
new_columns
# Out:
# {0: 'fixed acidity',
#  1: 'volatile acidity',
#  2: 'citric acid',
#  3: 'residual sugar',
#  4: 'chlorides',
#  5: 'free sulfur dioxide',
#  6: 'total sulfur dioxide',
#  7: 'density',
#  8: 'pH',
#  9: 'sulphates',
#  10: 'alcohol',
#  11: 'quality'}

# %%
for key, value in new_columns.items():
    print(key, value)
    red_wines[value] = rows[:,key]
# Out:
# 0 fixed acidity
# 1 volatile acidity
# 2 citric acid
# 3 residual sugar
# 4 chlorides
# 5 free sulfur dioxide
# 6 total sulfur dioxide
# 7 density
# 8 pH
# 9 sulphates
# 10 alcohol
# 11 quality

# %%
red_wines
# Out:
#      fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"  \
# 0      7.4,0.7,0,1.9,0.076,11,34,0.9978,3.51,0.56,9.4,5
# 1      7.8,0.88,0,2.6,0.098,25,67,0.9968,3.2,0.68,9.8,5
# 2     7.8,0.76,0.04,2.3,0.092,15,54,0.997,3.26,0.65,...
# 3     11.2,0.28,0.56,1.9,0.075,17,60,0.998,3.16,0.58...
# 4      7.4,0.7,0,1.9,0.076,11,34,0.9978,3.51,0.56,9.4,5
# ...                                                 ...
# 1594  6.2,0.6,0.08,2,0.09,32,44,0.9949,3.45,0.58,10.5,5
# 1595  5.9,0.55,0.1,2.2,0.062,39,51,0.99512,3.52,0.76...
# 1596  6.3,0.51,0.13,2.3,0.076,29,40,0.99574,3.42,0.7...
# 1597  5.9,0.645,0.12,2,0.075,32,44,0.99547,3.57,0.71...
# 1598  6,0.31,0.47,3.6,0.067,18,42,0.99549,3.39,0.66,...
#
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# ...

# %%
red_wines = red_wines.drop(columns = ['fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"'])

# %%
red_wines_quality = red_wines.quality.mean()

# %%
red_wines_alcohol =  red_wines.alcohol.mean()
red_wines_alcohol
# Out:
# 10.422983114446502

# %%
round(red_wines_alcohol/red_wines_quality,2)
# Out:
# 1.85

# %%
white_wines = pd.read_csv('Data exercice/winequality-white.csv')

# %%
white_wines
# Out:
#      fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 0      7;0.27;0.36;20.7;0.045;45;170;1.001;3;0.45;8.8;6
# 1     6.3;0.3;0.34;1.6;0.049;14;132;0.994;3.3;0.49;9...
# 2     8.1;0.28;0.4;6.9;0.05;30;97;0.9951;3.26;0.44;1...
# 3     7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...
# 4     7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...
# ...                                                 ...
# 4893  6.2;0.21;0.29;1.6;0.039;24;92;0.99114;3.27;0.5...
# 4894  6.6;0.32;0.36;8;0.047;57;168;0.9949;3.15;0.46;...
# 4895  6.5;0.24;0.19;1.2;0.041;30;111;0.99254;2.99;0....
# 4896  5.5;0.29;0.3;1.1;0.022;20;110;0.98869;3.34;0.3...
# 4897  6;0.21;0.38;0.8;0.02;22;98;0.98941;3.26;0.32;1...
#
# [4898 rows x 1 columns]

# %%
rows = []
for data in white_wines.values:
    new_data= data[0].replace(';', ',').split(',')
    new_data = list(map(float, new_data))
    rows.append(new_data)
    # print(new_data, len(new_data))
rows = np.array(rows)
rows
# Out:
# array([[ 7.  ,  0.27,  0.36, ...,  0.45,  8.8 ,  6.  ],
#        [ 6.3 ,  0.3 ,  0.34, ...,  0.49,  9.5 ,  6.  ],
#        [ 8.1 ,  0.28,  0.4 , ...,  0.44, 10.1 ,  6.  ],
#        ...,
#        [ 6.5 ,  0.24,  0.19, ...,  0.46,  9.4 ,  6.  ],
#        [ 5.5 ,  0.29,  0.3 , ...,  0.38, 12.8 ,  7.  ],
#        [ 6.  ,  0.21,  0.38, ...,  0.32, 11.8 ,  6.  ]])

# %%
for key, value in new_columns.items():
    print(key, value)
    white_wines[value] = rows[:,key]
white_wines = white_wines.drop(columns = ['fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"'])
# Out:
# 0 fixed acidity
# 1 volatile acidity
# 2 citric acid
# 3 residual sugar
# 4 chlorides
# 5 free sulfur dioxide
# 6 total sulfur dioxide
# 7 density
# 8 pH
# 9 sulphates
# 10 alcohol
# 11 quality

# %%
white_wines_quality = white_wines.quality.mean()

# %%
white_wines_alcohol =  white_wines.alcohol.mean()

# %%
white_wines_alcohol, round(white_wines_alcohol/white_wines_quality, 2)
# Out:
# (10.514267047774638, 1.79)
