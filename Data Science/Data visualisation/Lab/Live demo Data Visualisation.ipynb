# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Visualisation and EDA Live Demo

# %% [markdown]
# ## Ploting in Matplotlib

# %% [markdown]
# ### World Hapinness Report Dataset

# %%
report_2019 = pd.read_csv('Data/2019.csv')

# %%
report_2018 = pd.read_csv('Data/2018.csv')

# %%
report_2017 = pd.read_csv('Data/2017.csv')

# %%
report_2019
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
report_2019.dtypes
# Out:
# Overall rank                      int64
# Country or region                object
# Score                           float64
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# dtype: object

# %%
report_2019.describe().T
# Out:
#                               count       mean        std    min       25%  \
# Overall rank                  156.0  78.500000  45.177428  1.000  39.75000
# Score                         156.0   5.407096   1.113120  2.853   4.54450
# GDP per capita                156.0   0.905147   0.398389  0.000   0.60275
# Social support                156.0   1.208814   0.299191  0.000   1.05575
# Healthy life expectancy       156.0   0.725244   0.242124  0.000   0.54775
# Freedom to make life choices  156.0   0.392571   0.143289  0.000   0.30800
# Generosity                    156.0   0.184846   0.095254  0.000   0.10875
# Perceptions of corruption     156.0   0.110603   0.094538  0.000   0.04700
#
#                                   50%        75%      max
# Overall rank                  78.5000  117.25000  156.000
# Score                          5.3795    6.18450    7.769
# GDP per capita                 0.9600    1.23250    1.684
# Social support                 1.2715    1.45250    1.624
# ...

# %%
report_2018
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.632           1.305
# 1               2                    Norway  7.594           1.456
# 2               3                   Denmark  7.555           1.351
# 3               4                   Iceland  7.495           1.343
# 4               5               Switzerland  7.487           1.420
# ..            ...                       ...    ...             ...
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.592                    0.874                         0.681
# ...

# %%
report_2018.dtypes
# Out:
# Overall rank                      int64
# Country or region                object
# Score                           float64
# GDP per capita                  float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# dtype: object

# %%
report_2018.describe().T
# Out:
#                               count       mean        std    min       25%  \
# Overall rank                  156.0  78.500000  45.177428  1.000  39.75000
# Score                         156.0   5.375917   1.119506  2.905   4.45375
# GDP per capita                156.0   0.891449   0.391921  0.000   0.61625
# Social support                156.0   1.213237   0.302372  0.000   1.06675
# Healthy life expectancy       156.0   0.597346   0.247579  0.000   0.42225
# Freedom to make life choices  156.0   0.454506   0.162424  0.000   0.35600
# Generosity                    156.0   0.181006   0.098471  0.000   0.10950
# Perceptions of corruption     155.0   0.112000   0.096492  0.000   0.05100
#
#                                   50%        75%      max
# Overall rank                  78.5000  117.25000  156.000
# Score                          5.3780    6.16850    7.632
# GDP per capita                 0.9495    1.19775    2.096
# Social support                 1.2550    1.46300    1.644
# ...

# %%
# Plot histogram
plt.hist(report_2018['GDP per capita'])
plt.xlabel('GDP contribution')
plt.ylabel('Count')
plt.show()

# %%
report_2018['GDP per capita'].mean()
# Out:
# 0.8914487179487178

# %%
# Missing data
report_2018[report_2018['GDP per capita'] > 1.5].sort_values('GDP per capita')
# Out:
#     Overall rank     Country or region  Score  GDP per capita  Social support  \
# 33            34             Singapore  6.343           1.529           1.451
# 16            17            Luxembourg  6.910           1.576           1.520
# 31            32                 Qatar  6.374           1.649           1.303
# 19            20  United Arab Emirates  6.774           2.096           0.776
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 33                    1.008                         0.631       0.261
# 16                    0.896                         0.632       0.196
# 31                    0.748                         0.654       0.256
# 19                    0.670                         0.284       0.186
#
#     Perceptions of corruption
# 33                      0.457
# 16                      0.321
# 31                      0.171
# 19                        NaN

# %%
report_2018.nsmallest(10, 'GDP per capita')
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 97             98                   Somalia  4.982           0.000
# 154           155  Central African Republic  3.083           0.024
# 131           132          Congo (Kinshasa)  4.245           0.069
# 148           149                   Liberia  3.495           0.076
# 155           156                   Burundi  2.905           0.091
# 133           134                     Niger  4.166           0.131
# 146           147                    Malawi  3.587           0.186
# 122           123                Mozambique  4.417           0.198
# 112           113              Sierra Leone  4.571           0.256
# 138           139                      Togo  3.999           0.259
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 97            0.712                    0.115                         0.674
# 154           0.000                    0.010                         0.305
# ...

# %%
plt.hist(report_2018.nsmallest(20, 'GDP per capita')['GDP per capita'])
plt.show()

# %%
report_2019[report_2019['GDP per capita'] > 1.5].sort_values('GDP per capita')
# Out:
#     Overall rank     Country or region  Score  GDP per capita  Social support  \
# 20            21  United Arab Emirates  6.825           1.503           1.310
# 33            34             Singapore  6.262           1.572           1.463
# 13            14            Luxembourg  7.090           1.609           1.479
# 28            29                 Qatar  6.374           1.684           1.313
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 20                    0.825                         0.598       0.262
# 33                    1.141                         0.556       0.271
# 13                    1.012                         0.526       0.194
# 28                    0.871                         0.555       0.220
#
#     Perceptions of corruption
# 20                      0.182
# 33                      0.453
# 13                      0.316
# 28                      0.167

# %%
# Plot two datasets 
plt.hist(report_2018['GDP per capita'], label = '2018', alpha = 0.7)
plt.hist(report_2019['GDP per capita'], label = '2019', alpha = 0.7)
plt.legend()
plt.xlabel('GDP contribution')
plt.ylabel('Count')
plt.show()

# %%
# Plot two datasets for score
plt.hist(report_2018['Score'], label = '2018', alpha = 0.7)
plt.hist(report_2019['Score'], label = '2019', alpha = 0.7)
plt.legend()
plt.xlabel('Score')
plt.ylabel('Count')
plt.show()

# %%
# Boxplot
plt.boxplot([report_2018['Score'],report_2019['Score']])
plt.xticks((1,2), ['2018', '2019'])
plt.show()

# %%
# Merging two datasets
report_2018.merge(report_2019, left_on = 'Country or region', right_on = 'Country or region')
# Out:
#      Overall rank_x         Country or region  Score_x  GDP per capita_x  \
# 0                 1                   Finland    7.632             1.305
# 1                 2                    Norway    7.594             1.456
# 2                 3                   Denmark    7.555             1.351
# 3                 4                   Iceland    7.495             1.343
# 4                 5               Switzerland    7.487             1.420
# ..              ...                       ...      ...               ...
# 147             152                     Yemen    3.355             0.442
# 148             153                  Tanzania    3.303             0.455
# 149             154               South Sudan    3.254             0.337
# 150             155  Central African Republic    3.083             0.024
# 151             156                   Burundi    2.905             0.091
#
#      Social support_x  Healthy life expectancy_x  \
# ...

# %%
# Replace x and y suffixes
merged_reports = report_2018.merge(report_2019, left_on = 'Country or region', right_on = 'Country or region', suffixes = ['_2018', '_2019'] )

# %%
merged_reports
# Out:
#      Overall rank_2018         Country or region  Score_2018  \
# 0                    1                   Finland       7.632
# 1                    2                    Norway       7.594
# 2                    3                   Denmark       7.555
# 3                    4                   Iceland       7.495
# 4                    5               Switzerland       7.487
# ..                 ...                       ...         ...
# 147                152                     Yemen       3.355
# 148                153                  Tanzania       3.303
# 149                154               South Sudan       3.254
# 150                155  Central African Republic       3.083
# 151                156                   Burundi       2.905
#
#      GDP per capita_2018  Social support_2018  Healthy life expectancy_2018  \
# 0                  1.305                1.592                         0.874
# 1                  1.456                1.582                         0.861
# ...

# %%
scores = merged_reports[['Country or region', 'Score_2018', 'Score_2019']]

# %%
scores
# Out:
#             Country or region  Score_2018  Score_2019
# 0                     Finland       7.632       7.769
# 1                      Norway       7.594       7.554
# 2                     Denmark       7.555       7.600
# 3                     Iceland       7.495       7.494
# 4                 Switzerland       7.487       7.480
# ..                        ...         ...         ...
# 147                     Yemen       3.355       3.380
# 148                  Tanzania       3.303       3.231
# 149               South Sudan       3.254       2.853
# 150  Central African Republic       3.083       3.083
# 151                   Burundi       2.905       3.775
#
# [152 rows x 3 columns]

# %%
scores.nlargest(20, 'Score_2018')
# Out:
#        Country or region  Score_2018  Score_2019
# 0                Finland       7.632       7.769
# 1                 Norway       7.594       7.554
# 2                Denmark       7.555       7.600
# 3                Iceland       7.495       7.494
# 4            Switzerland       7.487       7.480
# 5            Netherlands       7.441       7.488
# 6                 Canada       7.328       7.278
# 7            New Zealand       7.324       7.307
# 8                 Sweden       7.314       7.343
# 9              Australia       7.272       7.228
# 10        United Kingdom       7.190       7.054
# 11               Austria       7.139       7.246
# 12            Costa Rica       7.072       7.167
# 13               Ireland       6.977       7.021
# 14               Germany       6.965       6.985
# 15               Belgium       6.927       6.923
# 16            Luxembourg       6.910       7.090
# 17         United States       6.886       6.892
# ...

# %%
# Bar charts are used to plot categorical variables
plt.barh(scores.nlargest(20, 'Score_2018')['Country or region'], scores.nlargest(20, 'Score_2018')['Score_2018'])
plt.xlim(0, 8)
plt.gca().invert_yaxis()
plt.show()

# %%
# Bar charts are used to plot categorical variables
plt.barh(scores.nsmallest(20, 'Score_2018')['Country or region'], scores.nsmallest(20, 'Score_2018')['Score_2018'])
plt.xlim(0, 8)
plt.show()

# %%
# Set the size of the plot - tuple values are measured in inches
plt.figure(figsize=(20,20))
plt.barh(scores.nsmallest(20, 'Score_2018')['Country or region'], scores.nsmallest(20, 'Score_2018')['Score_2018'])
plt.xlim(0, 8)
plt.show()

# %%
# Pie chart is also used for categorial variables
plt.pie([1, 5, 8], labels = ['a', 'b', 'c'])
plt.show()

# %%
merged_reports = merged_reports.merge(report_2017.rename(columns = lambda col: col + '_2017'), left_on = 'Country or region', right_on = 'Country_2017', suffixes=['', ' 2017'])

# %%
merged_reports
# Out:
#      Overall rank_2018         Country or region  Score_2018  \
# 0                    1                   Finland       7.632
# 1                    2                    Norway       7.594
# 2                    3                   Denmark       7.555
# 3                    4                   Iceland       7.495
# 4                    5               Switzerland       7.487
# ..                 ...                       ...         ...
# 142                152                     Yemen       3.355
# 143                153                  Tanzania       3.303
# 144                154               South Sudan       3.254
# 145                155  Central African Republic       3.083
# 146                156                   Burundi       2.905
#
#      GDP per capita_2018  Social support_2018  Healthy life expectancy_2018  \
# 0                  1.305                1.592                         0.874
# 1                  1.456                1.582                         0.861
# ...

# %%
merged_reports = merged_reports.rename(columns = {'Happiness.Score_2017': 'Score_2017'})

# %%
merged_reports
# Out:
#      Overall rank_2018         Country or region  Score_2018  \
# 0                    1                   Finland       7.632
# 1                    2                    Norway       7.594
# 2                    3                   Denmark       7.555
# 3                    4                   Iceland       7.495
# 4                    5               Switzerland       7.487
# ..                 ...                       ...         ...
# 142                152                     Yemen       3.355
# 143                153                  Tanzania       3.303
# 144                154               South Sudan       3.254
# 145                155  Central African Republic       3.083
# 146                156                   Burundi       2.905
#
#      GDP per capita_2018  Social support_2018  Healthy life expectancy_2018  \
# 0                  1.305                1.592                         0.874
# 1                  1.456                1.582                         0.861
# ...

# %%
scores = merged_reports[['Country or region', 'Score_2017', 'Score_2018', 'Score_2019']]

# %%
scores
# Out:
#             Country or region  Score_2017  Score_2018  Score_2019
# 0                     Finland       7.469       7.632       7.769
# 1                      Norway       7.537       7.594       7.554
# 2                     Denmark       7.522       7.555       7.600
# 3                     Iceland       7.504       7.495       7.494
# 4                 Switzerland       7.494       7.487       7.480
# ..                        ...         ...         ...         ...
# 142                     Yemen       3.593       3.355       3.380
# 143                  Tanzania       3.349       3.303       3.231
# 144               South Sudan       3.591       3.254       2.853
# 145  Central African Republic       2.693       3.083       3.083
# 146                   Burundi       2.905       2.905       3.775
#
# [147 rows x 4 columns]

# %%
# Matplotlib cannot plot rows. This can be fixed by transpose.Values takes only values, ravel makes values one-dimensional array.
bg_scores = scores[scores['Country or region'] == 'Bulgaria'].T.drop('Country or region').values.ravel()
romania_scores = scores[scores['Country or region'] == 'Romania'].T.drop('Country or region').values.ravel()

# %%
bg_scores
# Out:
# array([4.71400022506714, 4.933, 5.011], dtype=object)

# %%
years = list(range(2017,2020))

# %%
plt.plot(years, bg_scores, label = 'Bulgaria', linewidth = 2, linestyle = 'dashed')
plt.scatter(years, bg_scores, marker= 's', s = 50)

plt.plot(years, romania_scores, label = 'Romania', linewidth = 2, linestyle = 'dashed')
plt.scatter(years, romania_scores, marker= 's', s = 50)

plt.legend(loc = 'lower right')
plt.xticks(years)
plt.title('Bulgaria happiness score')
plt.xlabel('Year')
plt.ylabel('Score')
plt.show()
